# %%
def add_item(item, items=None):
    if items is None:
        items = []
    items.append(item)
    return item

print(add_item("사과"))
print(add_item("바나나"))
# Out:
# 사과
# 바나나

# %%
def average(numbers):
    total = sum(numbers)
    return total / len(numbers)

print(average([]))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 5
#       1 def average(numbers):
#       2     total = sum(numbers)
#       3     return total / len(numbers)
#       4
# ----> 5 print(average([]))
#
# Cell In[2], line 3, in average(numbers)
#       1 def average(numbers):
#       2     total = sum(numbers)
# ----> 3     return total / len(numbers)
#
# ZeroDivisionError: division by zero
