# %%
import pandas as pd
pd.__version__
# Out:
# '3.0.5'

# %%
score = [['홍길동', 100, 90, 80]]
score_df = pd.DataFrame(score, columns=['이름', '국어', '영어', '수학'])
score_df
# Out:
#     이름   국어  영어  수학
# 0  홍길동  100  90  80

# %%
score_df.reset_index(drop=True)
# Out:
#     이름   국어  영어  수학
# 0  홍길동  100  90  80
